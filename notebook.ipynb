# %%
import fastf1
import os

# %%
if not os.path.exists('.fastf1-cache'):
        os.makedirs('.fastf1-cache')

# Enable local cache
fastf1.Cache.enable_cache('.fastf1-cache')

# %%
session = fastf1.get_session(2025, 1, "R")
print(session)
# Out:
# 2025 Season Round 1: Australian Grand Prix - Race

# %% [markdown]
# importante hacer un load de lo que vayamos a usar antes de extraer datos

# %%
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
session.car_data
# Out:
# {'4':                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source  \
#  0     2025-03-16 03:12:38.929  0.0    0.0      0       0.0  False    0    car
#  1     2025-03-16 03:12:39.204  0.0    0.0      0       0.0  False    0    car
#  2     2025-03-16 03:12:39.444  0.0    0.0      0       0.0  False    0    car
#  3     2025-03-16 03:12:39.724  0.0    0.0      0       0.0  False    0    car
#  4     2025-03-16 03:12:39.924  0.0    0.0      0       0.0  False    0    car
#  ...                       ...  ...    ...    ...       ...    ...  ...    ...
#  38416 2025-03-16 06:04:33.849  0.0    0.0      0     104.0   True    0    car
#  38417 2025-03-16 06:04:34.369  0.0    0.0      0     104.0   True    0    car
#  38418 2025-03-16 06:04:34.528  0.0    0.0      0     104.0   True    0    car
#  38419 2025-03-16 06:04:34.768  0.0    0.0      0     104.0   True    0    car
#  38420 2025-03-16 06:04:35.009  0.0    0.0      0     104.0   True    0    car
#
# ...

# %%
event = fastf1.get_event(2025, 12)
print(event)
# Out:
# RoundNumber                                                       12
# Country                                               United Kingdom
# Location                                                 Silverstone
# OfficialEventName    FORMULA 1 QATAR AIRWAYS BRITISH GRAND PRIX 2025
# EventDate                                        2025-07-06 00:00:00
# EventName                                         British Grand Prix
# EventFormat                                             conventional
# Session1                                                  Practice 1
# Session1Date                               2025-07-04 12:30:00+01:00
# Session1DateUtc                                  2025-07-04 11:30:00
# Session2                                                  Practice 2
# Session2Date                               2025-07-04 16:00:00+01:00
# Session2DateUtc                                  2025-07-04 15:00:00
# Session3                                                  Practice 3
# ...

# %%
p1 = event.get_practice(1)
print(p1)
# Out:
# 2025 Season Round 12: British Grand Prix - Practice 1

# %%
p1.load()
# Out:
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
p1.drivers
# Out:
# ['1',
#  '4',
#  '5',
#  '6',
#  '10',
#  '12',
#  '14',
#  '16',
#  '18',
#  '23',
#  '30',
#  '31',
#  '36',
#  '43',
#  '44',
#  '55',
#  '63',
#  '81',
#  '87',
#  '97']

# %%
p1.session_info
# Out:
# {'Meeting': {'Key': 1277,
#   'Name': 'British Grand Prix',
#   'OfficialName': 'FORMULA 1 QATAR AIRWAYS BRITISH GRAND PRIX 2025',
#   'Location': 'Silverstone',
#   'Number': 12,
#   'Country': {'Key': 2, 'Code': 'GBR', 'Name': 'United Kingdom'},
#   'Circuit': {'Key': 2, 'ShortName': 'Silverstone'}},
#  'SessionStatus': 'Inactive',
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 9940,
#  'Type': 'Practice',
#  'Number': 1,
#  'Name': 'Practice 1',
#  'StartDate': datetime.datetime(2025, 7, 4, 12, 30),
#  'EndDate': datetime.datetime(2025, 7, 4, 13, 30),
#  'GmtOffset': datetime.timedelta(seconds=3600),
#  'Path': '2025/2025-07-06_British_Grand_Prix/2025-07-04_Practice_1/'}

# %%
quali = event.get_qualifying()
quali.load()
# Out:
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
quali.race_control_messages
# Out:
#                   Time Category  \
# 0  2025-07-05 14:00:00     Flag
# 1  2025-07-05 14:09:43     Flag
# 2  2025-07-05 14:09:44     Flag
# 3  2025-07-05 14:09:59     Flag
# 4  2025-07-05 14:10:13     Flag
# 5  2025-07-05 14:11:02     Flag
# 6  2025-07-05 14:11:11     Flag
# 7  2025-07-05 14:11:12     Flag
# 8  2025-07-05 14:17:30    Other
# 9  2025-07-05 14:17:39     Flag
# 10 2025-07-05 14:17:40      Drs
# 11 2025-07-05 14:21:00     Flag
# 12 2025-07-05 14:23:15    Other
# 13 2025-07-05 14:25:11    Other
# 14 2025-07-05 14:27:49     Flag
# 15 2025-07-05 14:28:00    Other
# 16 2025-07-05 14:29:54     Flag
# 17 2025-07-05 14:30:36    Other
# 18 2025-07-05 14:31:06    Other
# 19 2025-07-05 14:31:37     Flag
# 20 2025-07-05 14:35:00     Flag
# 21 2025-07-05 14:50:00     Flag
# 22 2025-07-05 14:50:16    Other
# 23 2025-07-05 14:53:05    Other
# 24 2025-07-05 14:53:30    Other
# 25 2025-07-05 14:53:53    Other
# 26 2025-07-05 14:58:00     Flag
# 27 2025-07-05 15:10:00     Flag
# ...

# %%
quali.car_data
# Out:
# {'1':                          Date      RPM  Speed  nGear  Throttle  Brake  DRS  \
#  0     2025-07-05 13:46:27.157   3614.0    0.0      0       0.0  False    8
#  1     2025-07-05 13:46:27.397   3497.0    0.0      0       0.0  False    8
#  2     2025-07-05 13:46:27.637   3528.0    0.0      0       0.0  False    8
#  3     2025-07-05 13:46:27.797   3546.0    0.0      0       0.0  False    8
#  4     2025-07-05 13:46:28.037   3515.0    0.0      0       0.0  False    8
#  ...                       ...      ...    ...    ...       ...    ...  ...
#  19089 2025-07-05 15:12:34.440  10634.0  212.0      5     104.0   True    8
#  19090 2025-07-05 15:12:34.840  10634.0  212.0      5     104.0   True    8
#  19091 2025-07-05 15:12:35.120  10634.0  212.0      5     104.0   True    8
#  19092 2025-07-05 15:12:35.320  10634.0  212.0      5     104.0   True    8
#  19093 2025-07-05 15:12:35.521  10634.0  212.0      5     104.0   True    8
#
# ...

# %%
quali.get_circuit_info()
# Out:
# CircuitInfo(corners=              X             Y  Number Letter       Angle     Distance
# 0   1192.508301   4503.826172       1          98.489924   447.845252
# 1   2770.315186   4462.892090       2         -78.034630   607.958951
# 2   4845.322266   5895.130371       3          98.255545   841.440981
# 3   5802.704102   4733.524414       4         -75.863925  1022.486368
# 4   6232.291016   6458.979492       5          19.104730  1204.667204
# 5    631.385986  10910.232422       6         108.305663  1949.196078
# 6   -566.251648   9540.383789       7        -130.008187  2168.698329
# 7    761.338562  12361.558594       8         122.633898  2512.187222
# 8   5893.893555  12947.209961       9          59.405497  3041.750409
# 9   7295.830078   7780.465820      10        -159.332725  3635.287930
# 10  7534.993164   6906.171875      11          -0.752108  3694.355503
# 11  7336.696289   5474.734863      12           6.130681  3830.117313
# ...

# %%
quali.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:18:20.889000    VER            1                    NaT
# 1   0 days 00:19:46.930000    VER            1 0 days 00:01:26.041000
# 2   0 days 00:21:45.843000    VER            1 0 days 00:01:58.913000
# 3   0 days 00:37:07.870000    VER            1                    NaT
# 4   0 days 00:38:33.756000    VER            1 0 days 00:01:25.886000
# ..                     ...    ...          ...                    ...
# 286 0 days 00:17:40.550000    COL           43 0 days 00:01:27.060000
# 287 0 days 00:19:44.715000    COL           43 0 days 00:02:04.165000
# 288 0 days 00:21:49.515000    COL           43 0 days 00:02:04.800000
# 289 0 days 00:23:43.678000    COL           43 0 days 00:01:54.163000
# 290 0 days 00:27:25.205000    COL           43                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
quali.get_driver("PIA")
# Out:
# DriverNumber                                                         81
# BroadcastName                                                 O PIASTRI
# Abbreviation                                                        PIA
# DriverId                                                        piastri
# TeamName                                                        McLaren
# TeamColor                                                        F47600
# TeamId                                                          mclaren
# FirstName                                                         Oscar
# LastName                                                        Piastri
# FullName                                                  Oscar Piastri
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode
# Position                                                            2.0
# ClassifiedPosition
# GridPosition                                                        NaN
# ...

# %%
quali.weather_data
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:28.969000     19.5      75.0     995.3     False       25.3
# 1  0 days 00:01:28.963000     19.5      76.0     995.2     False       25.3
# 2  0 days 00:02:28.987000     19.4      76.0     995.3     False       25.3
# 3  0 days 00:03:28.984000     19.4      76.0     995.2     False       25.2
# 4  0 days 00:04:28.997000     19.4      76.0     995.2     False       25.3
# ..                    ...      ...       ...       ...       ...        ...
# 82 0 days 01:22:29.349000     21.3      66.0     994.4     False       29.0
# 83 0 days 01:23:29.349000     21.3      66.0     994.4     False       28.8
# 84 0 days 01:24:29.350000     21.3      65.0     994.5     False       29.0
# 85 0 days 01:25:29.351000     21.4      65.0     994.5     False       28.8
# 86 0 days 01:26:29.350000     21.4      66.0     994.6     False       28.8
#
#     WindDirection  WindSpeed
# ...

# %%
quali.t0_date
# Out:
# Timestamp('2025-07-05 13:46:25.741000')

# %%
quali.results
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 4             4      L NORRIS          NOR          norris          McLaren
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 10           10       P GASLY          GAS           gasly           Alpine
# 55           55       C SAINZ          SAI           sainz         Williams
# ...
